# %% [markdown]
# # Temas vistos el 23 de noviembre del 2022
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danielroa98/Postgrad-ML/blob/main/Module-1/23_Nov_2022_lec_05_M1G6P_DRG.ipynb)

# %% [markdown]
# Para información adicional de los ejercicios hechos anteriormente, ver el Notebook de la [lectura 4](./16_Nov_2022_lec_04_M1G6P_DRG.ipynb).

# %%
import pandas as pd
import numpy as np

# %%
emp = pd.read_csv('./Datasets/employees.csv', parse_dates=['hire_date'])
emp.head(6)
# Out:
#    employee_id first_name  last_name                  email  hire_date  \
# 0            1     Berrie    Manueau   bmanueau0@dion.ne.jp 2006-04-20
# 1            2    Aeriell      McNee      amcnee1@google.es 2009-01-26
# 2            3     Sydney    Symonds      ssymonds2@hhs.gov 2010-05-17
# 3            4      Avrom  Rowantree                    NaN 2014-02-08
# 4            5     Feliks    Morffew       fmorffew4@a8.net 2003-01-14
# 5            6    Bethena       Trow  btrow5@technorati.com 2003-08-06
#
#          department gender  salary  region_id
# 0            Sports      F  154864          4
# 1             Tools      F   56752          3
# 2          Clothing      F   95313          4
# 3  Phones & Tablets      M  119674          7
# 4         Computers      M   55307          5
# 5            Sports      F  134501          3

# %% [markdown]
# ### Continuación de ejercicios...

# %%
emp['salary'].describe()
# Out:
# count      1000.000000
# mean      91571.594000
# std       42028.902067
# min       20542.000000
# 25%       55292.250000
# 50%       89686.500000
# 75%      126997.750000
# max      166976.000000
# Name: salary, dtype: float64

# %% [markdown]
# #### 5) Utilizando los valores obtenidos por el método _describe_, construye una función que determine si el salario es:
# - 'bajo', si salario <= perecntil 25
# - 'medio' si el salario está entre percentil 25 (excluyendo) y el percentil 75 (inclusivo)
# - 'alto' si el salario mayor al percentil 75.

# %%
def salary_classifier(salary_value):
    if salary_value <= 55292.25:
        return 'bajo'
    elif salary_value <= 126997.75:
        return 'medio'
    else:
        return 'alto'

# %% [markdown]
# #### 6) Aplica la función del punto anterior para la columna salary para ver el resultado

# %%
emp['salary'].apply(salary_classifier)
# Sintaxis
# serie.apply(nombre_de_la_función)
# Out:
# 0       alto
# 1      medio
# 2      medio
# 3      medio
# 4      medio
#        ...
# 995    medio
# 996    medio
# 997     alto
# 998     bajo
# 999     bajo
# Name: salary, Length: 1000, dtype: object

# %% [markdown]
# Se podía definir una columna nueva para guardar estos resultados
# ```
# emp['salary_range'] = emp['salary'].apply(salary_classifier)
# ```

# %% [markdown]
# #### 7) ¿Cuántos salarios bajos, medios y altos hay?

# %%
emp['salary'].apply(salary_classifier).value_counts()
# Out:
# medio    500
# alto     250
# bajo     250
# Name: salary, dtype: int64

# %% [markdown]
# #### 8) Se quieren los resultados de la pregunta 7 en frecuencias relativas.

# %%
emp['salary'].apply(salary_classifier).value_counts(normalize=True)*100
# Out:
# medio    50.0
# alto     25.0
# bajo     25.0
# Name: salary, dtype: float64

# %% [markdown]
# #### 9) ¿Cuántos departamentos hay?

# %%
emp['department'].nunique()
# Lo anterior es como utilizar emp['department'].unique() y después contarlos.
# Out:
# 27

# %% [markdown]
# #### 10) Supongamos que a todos los empleados se les dará un aumento del 10%, crear una nueva columna llamada 'new_salary' que contenga el nuevo salario

# %%
emp['new_salary'] = emp['salary'].apply(lambda x:x*1.1)

# %% [markdown]
# #### Alternativa utilizando broadcasting
# ```emp['new_salary'] = emp['salary']*1.1```

# %%
emp.head()
# Out:
#    employee_id first_name  last_name                 email  hire_date  \
# 0            1     Berrie    Manueau  bmanueau0@dion.ne.jp 2006-04-20
# 1            2    Aeriell      McNee     amcnee1@google.es 2009-01-26
# 2            3     Sydney    Symonds     ssymonds2@hhs.gov 2010-05-17
# 3            4      Avrom  Rowantree                   NaN 2014-02-08
# 4            5     Feliks    Morffew      fmorffew4@a8.net 2003-01-14
#
#          department gender  salary  region_id  new_salary
# 0            Sports      F  154864          4    170350.4
# 1             Tools      F   56752          3     62427.2
# 2          Clothing      F   95313          4    104844.3
# 3  Phones & Tablets      M  119674          7    131641.4
# 4         Computers      M   55307          5     60837.7

# %% [markdown]
# #### 11) ¿Cuántos valores nulos tiene la columna 'email'?

# %%
emp['email'].isnull().sum()
# Out:
# 204

# %%
# Utilizando el alias
emp['email'].isna().sum()
# Out:
# 204

# %% [markdown]
# ## Creando un DataFrame, utilizando un diccionario

# %%
dic_data = {
    'producto': ['laptop', 'tabler', 'celular', 'reloj'],
    'precio': [3000, 13500, 2800, 19600]
}
df = pd.DataFrame(dic_data)
df
# Out:
#   producto  precio
# 0   laptop    3000
# 1   tabler   13500
# 2  celular    2800
# 3    reloj   19600

# %%
dic_2 = pd.DataFrame(dic_data, index=['prod1', 'prod2', 'prod3', 'prod4'])
dic_2
# Out:
#       producto  precio
# prod1   laptop    3000
# prod2   tabler   13500
# prod3  celular    2800
# prod4    reloj   19600

# %% [markdown]
# ##

# %%
emp = pd.read_csv('./Datasets/employees_2.csv')
emp.head(6)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male  4/18/1987         1:35 AM  115163   10.125
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services
# 5             False            Legal

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %% [markdown]
# Converting to datetime

# %%
pd.to_datetime(emp['Start Date'])
# Out:
# 0     1993-08-06
# 1     1996-03-31
# 2     1993-04-23
# 3     2005-03-04
# 4     1998-01-24
#          ...
# 995   2014-11-23
# 996   1984-01-31
# 997   2013-05-20
# 998   2013-04-20
# 999   2012-05-15
# Name: Start Date, Length: 1000, dtype: datetime64[ns]

# %%
emp['Start Date'] = pd.to_datetime(emp['Start Date'])
emp['Last Login Time'] = pd.to_datetime(emp['Last Login Time'])

emp.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-11-23 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-11-23 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-11-23 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-11-23 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-11-23 16:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 62.6+ KB

# %%
# emp['Senior Management'].value_counts()
emp['Senior Management'].unique()
# Cómo hay valores que no están definidos como booleanos, se van a definir así.
# Out:
# array([True, False, nan], dtype=object)

# %%
emp['Senior Management'] = emp['Senior Management'].astype('bool')
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 55.8+ KB

# %%
emp['Gender'] = emp['Gender'].astype('category')
emp.dtypes
# Out:
# First Name                   object
# Gender                     category
# Start Date           datetime64[ns]
# Last Login Time      datetime64[ns]
# Salary                        int64
# Bonus %                     float64
# Senior Management              bool
# Team                         object
# dtype: object

# %% [markdown]
# ## Filtrando DataFrames según ciertos criterios

# %%
emp.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-11-23 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-11-23 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-11-23 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-11-23 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-11-23 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %% [markdown]
# ### Utilizando máscaras booleanas

# %%
is_male = emp['Gender'] == 'Male'
is_male
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %% [markdown]
# Una forma para filtrar a los hombres puede ser de la siguiente manera:

# %%
# Sólo devuelve los renglones que cumplan la condición establecida anteriormente.
emp[is_male]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2022-11-23 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2022-11-23 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2022-11-23 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2022-11-23 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2022-11-23 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2022-11-23 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2022-11-23 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2022-11-23 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2022-11-23 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2022-11-23 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# El equivalente pero con menos paso sería lo siguiente:

# %%
emp[emp['Gender'] == 'Male']
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2022-11-23 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2022-11-23 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2022-11-23 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2022-11-23 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2022-11-23 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2022-11-23 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2022-11-23 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2022-11-23 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2022-11-23 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2022-11-23 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# Es el equivalente, solo que comprimido:
# | Original                           | Shortened                             |
# |------------------------------------|---------------------------------------|
# | is_male  = emp['Gender'] == 'Male' | emp [ emp [ 'Gender' ]  ==   'Male' ] |

# %% [markdown]
# ### Filtrar por columna __Team__

# %%
marketing = emp['Team'] == 'Marketing'
emp[marketing]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-11-23 12:42:00   97308    6.945
# 21     Matthew    Male 1995-09-05 2022-11-23 02:12:00  100612   13.645
# 26       Craig    Male 2000-02-27 2022-11-23 07:45:00   37598    7.757
# 43     Marilyn  Female 1980-12-07 2022-11-23 03:16:00   73524    5.207
# 62         NaN  Female 2007-06-12 2022-11-23 17:25:00   58112   19.414
# ..         ...     ...        ...                 ...     ...      ...
# 942       Lori  Female 2015-11-20 2022-11-23 13:15:00   75498    6.537
# 947        NaN    Male 2012-07-30 2022-11-23 15:07:00  107351    5.329
# 986      Donna  Female 1982-11-26 2022-11-23 07:04:00   82871   17.999
# 991       Rose  Female 2002-08-25 2022-11-23 05:12:00  134505   11.051
# 994     George    Male 2013-06-21 2022-11-23 17:47:00   98874    4.479
#
#      Senior Management       Team
# 0                 True  Marketing
# 21               False  Marketing
# ...

# %%
# Para corroborar que si funcionó la máscara booleana
emp[marketing]['Team'].unique()
# Out:
# array(['Marketing'], dtype=object)

# %% [markdown]
# #### Filtrar a los empleados que son Senior Management

# %% [markdown]
# Esto se puede hacer ya que se están manejando valores booleanos en la serie _Senior Management_, entonces actúa como una máscara booleana por default.

# %%
sm = emp['Senior Management']
sm
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Senior Management, Length: 1000, dtype: bool

# %%
emp[emp['Senior Management']]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-11-23 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-11-23 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2022-11-23 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-11-23 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2022-11-23 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2022-11-23 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-11-23 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2022-11-23 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2022-11-23 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2022-11-23 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
emp['Team'].value_counts()
# Out:
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: Team, dtype: int64

# %% [markdown]
# #### Extraer a todos menos a los de legal

# %%
not_legal = emp['Team'] != 'Legal'
not_legal
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Name: Team, Length: 1000, dtype: bool

# %% [markdown]
# Se excluirán todos los registros que pertenezcan al equipo de _Legal_.

# %%
emp[not_legal]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-11-23 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-11-23 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-11-23 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-11-23 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-11-23 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-11-23 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-11-23 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-11-23 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-11-23 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-11-23 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# Corroborando

# %%
emp[not_legal]['Team'].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %% [markdown]
# #### Filtrar a los que __no son__ del área Legal y cuyo salario es mayor a la mediana

# %%
emp['Salary'].describe()
# Out:
# count      1000.000000
# mean      90662.181000
# std       32923.693342
# min       35013.000000
# 25%       62613.000000
# 50%       90428.000000
# 75%      118740.250000
# max      149908.000000
# Name: Salary, dtype: float64

# %%
emp[not_legal][emp[not_legal]['Salary']>90428]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-11-23 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2022-11-23 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-11-23 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-11-23 16:47:00  101004    1.389
# 8       Angela  Female 2005-11-22 2022-11-23 06:29:00   95570   18.523
# ..         ...     ...        ...                 ...     ...      ...
# 992    Anthony    Male 2011-10-16 2022-11-23 08:35:00  112769   11.625
# 994     George    Male 2013-06-21 2022-11-23 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2022-11-23 06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20 2022-11-23 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2022-11-23 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %% [markdown]
# Sintáxis de lo anterior:
# ```
# df[df[col_name] <boolean operation (==, !=, >, >=, <, <= )> conditional]
# ```

# %%
salary_gt_median = emp['Salary'] > 90428

# %%
emp[not_legal & salary_gt_median]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-11-23 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2022-11-23 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-11-23 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-11-23 16:47:00  101004    1.389
# 8       Angela  Female 2005-11-22 2022-11-23 06:29:00   95570   18.523
# ..         ...     ...        ...                 ...     ...      ...
# 992    Anthony    Male 2011-10-16 2022-11-23 08:35:00  112769   11.625
# 994     George    Male 2013-06-21 2022-11-23 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2022-11-23 06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20 2022-11-23 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2022-11-23 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %% [markdown]
# #### Filtrar a los empleados cuya fecha de inicio fue igual o antes al primero de febrero de 1988 (1988-02-01)

# %%
extracted_dates = emp['Start Date'] >= '1988-02-01'

# %%
emp[emp['Start Date'] >= '1988-02-01']
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-11-23 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-11-23 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-11-23 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-11-23 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-11-23 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2022-11-23 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2022-11-23 06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20 2022-11-23 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-11-23 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-11-23 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp[extracted_dates]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-11-23 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-11-23 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-11-23 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-11-23 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-11-23 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2022-11-23 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2022-11-23 06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20 2022-11-23 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-11-23 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-11-23 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp[extracted_dates]['Start Date'].min()
# Out:
# Timestamp('1988-02-02 00:00:00')

# %% [markdown]
# #### Filtrar por mas de una condición

# %% [markdown]
# Extraer a los hombres de Engineering

# %%
cond1 = emp['Gender'] == 'Male'
cond2 = emp['Team'] == 'Engineering'
emp[cond1 & cond2]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 171    Patrick   Male 2007-08-17 2022-11-23 03:16:00  143499   17.495
# 175     Willie   Male 1998-02-17 2022-11-23 20:20:00  146651    1.451
# 228      Bobby   Male 1994-09-23 2022-11-23 01:29:00   51685   17.445
# 242     Robert   Male 1990-10-27 2022-11-23 19:15:00   38041   18.428
# 245     Victor   Male 1991-04-11 2022-11-23 07:44:00   70817   17.138
# 283       Todd   Male 2009-03-11 2022-11-23 03:43:00  107281    1.612
# 300       Alan   Male 1988-06-26 2022-11-23 03:54:00  111786    3.592
# 301      James   Male 2015-07-11 2022-11-23 20:52:00   72257   13.023
# 329        NaN   Male 2010-01-27 2022-11-23 02:57:00   87760   14.987
# 343     Ronald   Male 2009-02-24 2022-11-23 14:09:00   96633    4.990
# 352        NaN   Male 2011-10-09 2022-11-23 09:29:00   69906    4.844
# 357    Russell   Male 2014-08-13 2022-11-23 15:51:00  121160    7.843
# ...

# %%
cond = emp['Team'].isnull()
emp[cond]
# Regresará todos los renglones donde Team sea Null (NaN).
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2022-11-23 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2022-11-23 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2022-11-23 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2022-11-23 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2022-11-23 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2022-11-23 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2022-11-23 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2022-11-23 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2022-11-23 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2022-11-23 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2022-11-23 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2022-11-23 06:06:00   66067   10.957
# ...

# %% [markdown]
# ### Using AND and OR
# #### (Name = 'Robert' and Team = 'Client Services') OR start_date > jun 2, 2016

# %%
c1 = emp['First Name'] == 'Robert'
c2 = emp['Team'] == 'Client Services'
c3 = emp['Start Date'] > '2016-06-02'

# %%
emp[(c1&c2)|c3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2022-11-23 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2022-11-23 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2022-11-23 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2022-11-23 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %%
emp.sort_values('Start Date', ascending=False)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 451      Terry     NaN 2016-07-15 2022-11-23 00:29:00  140002   19.490
# 98        Tina  Female 2016-06-16 2022-11-23 19:47:00  100705   16.961
# 15     Lillian  Female 2016-06-05 2022-11-23 06:09:00   59414    1.256
# 444        NaN    Male 2016-05-24 2022-11-23 21:17:00   76409    7.008
# 239    Lillian     NaN 2016-05-12 2022-11-23 15:43:00   64164   17.612
# ..         ...     ...        ...                 ...     ...      ...
# 549       Sara  Female 1980-02-25 2022-11-23 22:50:00   75484    3.186
# 272       Fred    Male 1980-02-20 2022-11-23 02:25:00   74129   18.225
# 881       Ruby  Female 1980-01-28 2022-11-23 23:08:00  142868    6.318
# 49       Chris     NaN 1980-01-24 2022-11-23 12:13:00  113590    3.055
# 954        Joe    Male 1980-01-19 2022-11-23 16:06:00  119667    1.148
#
#      Senior Management             Team
# 451               True        Marketing
# ...

# %% [markdown]
# ### Método .isin()

# %% [markdown]
# Una manera mas sencilla de extraer valores que hagan _match_ con varios criterios (o valores) es el método `isin()`.
#
# .isin() -> equivalente al `IN` en SQL.
#
# `columna.isin(list)`

# %%
cond = emp['First Name'].isin(['Angela','Ruby','Thomas'])

# %%
emp[cond]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-11-23 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2022-11-23 16:20:00   65476   10.012
# 8       Angela  Female 2005-11-22 2022-11-23 06:29:00   95570   18.523
# 74      Thomas    Male 1995-06-04 2022-11-23 14:24:00   62096   17.029
# 270     Thomas    Male 2011-04-06 2022-11-23 13:04:00  103235    9.554
# 279       Ruby  Female 2000-11-08 2022-11-23 19:35:00  105946    1.139
# 324       Ruby  Female 1988-12-10 2022-11-23 20:27:00   76707    6.031
# 350     Thomas     NaN 1995-08-31 2022-11-23 20:31:00   41549    3.950
# 541       Ruby  Female 1999-05-01 2022-11-23 03:36:00  147362    7.851
# 569       Ruby  Female 1980-07-07 2022-11-23 03:42:00  101262    6.773
# 704     Thomas    Male 1991-09-07 2022-11-23 09:51:00   65251   11.211
# 805     Thomas    Male 1990-05-03 2022-11-23 09:29:00  111371   15.081
# ...

# %%
cond = emp['Team'].notnull()

# %%
emp[cond]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-11-23 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2022-11-23 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-11-23 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-11-23 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2022-11-23 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-11-23 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-11-23 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-11-23 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-11-23 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-11-23 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB
